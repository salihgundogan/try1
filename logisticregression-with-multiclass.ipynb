# %% [markdown]
# <a href="https://www.kaggle.com/code/salihkeremgndoan/logisticregression-with-multiclass?scriptVersionId=255579165" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd 

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import matplotlib.pyplot as plt
from sklearn import linear_model
# %matplotlib inline

# %%
from sklearn.datasets import load_iris

iris = load_iris(as_frame=True)
print(iris.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
irises = load_iris()

# %%
dir(irises)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
irises.data[1]
# Out:
# array([4.9, 3. , 1.4, 0.2])

# %%
from sklearn.model_selection import train_test_split

# %%
X = irises.data
y = irises.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print(len(X))
print("train size:",len(X_train))
print("train size:",len(y_train))
print("test size:",len(X_test))
print("test size:",len(y_test))
# Out:
# 150
# train size: 120
# train size: 120
# test size: 30
# test size: 30

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=1000)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
model.predict(X_test)
# Out:
# array([1, 1, 2, 1, 2, 1, 1, 0, 1, 2, 0, 0, 2, 1, 2, 0, 2, 0, 2, 0, 1, 0,
#        0, 1, 1, 0, 1, 0, 2, 1])

# %%
model.score(X_test,y_test)
# Out:
# 0.9333333333333333

# %%
y_predicted = model.predict(X_test)

# %%
y_predicted
# Out:
# array([1, 1, 2, 1, 2, 1, 1, 0, 1, 2, 0, 0, 2, 1, 2, 0, 2, 0, 2, 0, 1, 0,
#        0, 1, 1, 0, 1, 0, 2, 1])

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test,y_predicted)
cm
# Out:
# array([[10,  0,  0],
#        [ 0, 10,  0],
#        [ 0,  2,  8]])

# %%
import seaborn as sn

# %%
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Modelle Tahminlenen')
plt.ylabel('Gerçek Değer')
# Out:
# Text(95.72222222222221, 0.5, 'Gerçek Değer')
